# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
passangers = pd.read_csv("../data/passengers.csv")

# %% [markdown]
# # Задание 1

# %%
# Коррекция для каждого смещения от 1 до 50
for i in range(1, 51):
    passangers[f'lag_{i}'] = passangers['#Passengers'].shift(-i)

# %%
passangers
# Out:
#        Month  #Passengers  lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  \
# 0    1949-01          112  118.0  132.0  129.0  121.0  135.0  148.0  148.0
# 1    1949-02          118  132.0  129.0  121.0  135.0  148.0  148.0  136.0
# 2    1949-03          132  129.0  121.0  135.0  148.0  148.0  136.0  119.0
# 3    1949-04          129  121.0  135.0  148.0  148.0  136.0  119.0  104.0
# 4    1949-05          121  135.0  148.0  148.0  136.0  119.0  104.0  118.0
# ..       ...          ...    ...    ...    ...    ...    ...    ...    ...
# 139  1960-08          606  508.0  461.0  390.0  432.0    NaN    NaN    NaN
# 140  1960-09          508  461.0  390.0  432.0    NaN    NaN    NaN    NaN
# 141  1960-10          461  390.0  432.0    NaN    NaN    NaN    NaN    NaN
# 142  1960-11          390  432.0    NaN    NaN    NaN    NaN    NaN    NaN
# 143  1960-12          432    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
passangers1 = passangers.drop(columns =['Month']).to_numpy()
corr = np.corrcoef(passangers1)
corr
# Out:
# array([[1.        , 0.89135655, 0.75590941, ...,        nan,        nan,
#                nan],
#        [0.89135655, 1.        , 0.89475501, ...,        nan,        nan,
#                nan],
#        [0.75590941, 0.89475501, 1.        , ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]])

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Задание 2

# %%
import statsmodels.api as sm

acf = sm.graphics.tsa.plot_pacf(passangers["#Passengers"])
acf
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
passangers.plot(x = "Month", y = ["lag_1", "lag_50", "#Passengers"])
plt.show()

# %% [markdown]
# # Задание 3

# %%
births = pd.read_csv("../data/births.csv")
births
# Out:
#            Date  Births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %%
# Коррекция для каждого смещения от 1 до 50
for i in range(1, 51):
    births[f'lag_{i}'] = births['Births'].shift(-i)

# %%
births
# Out:
#            Date  Births  lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  \
# 0    1959-01-01      35   32.0   30.0   31.0   44.0   29.0   45.0   43.0
# 1    1959-01-02      32   30.0   31.0   44.0   29.0   45.0   43.0   38.0
# 2    1959-01-03      30   31.0   44.0   29.0   45.0   43.0   38.0   27.0
# 3    1959-01-04      31   44.0   29.0   45.0   43.0   38.0   27.0   38.0
# 4    1959-01-05      44   29.0   45.0   43.0   38.0   27.0   38.0   33.0
# ..          ...     ...    ...    ...    ...    ...    ...    ...    ...
# 360  1959-12-27      37   52.0   48.0   55.0   50.0    NaN    NaN    NaN
# 361  1959-12-28      52   48.0   55.0   50.0    NaN    NaN    NaN    NaN
# 362  1959-12-29      48   55.0   50.0    NaN    NaN    NaN    NaN    NaN
# 363  1959-12-30      55   50.0    NaN    NaN    NaN    NaN    NaN    NaN
# 364  1959-12-31      50    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#      lag_8  ...  lag_41  lag_42  lag_43  lag_44  lag_45  lag_46  lag_47  \
# ...

# %%
births1 = births.drop(columns =['Date']).to_numpy()
corr_b = np.corrcoef(births1)
corr_b
# Out:
# array([[1.        , 0.06713092, 0.17261175, ...,        nan,        nan,
#                nan],
#        [0.06713092, 1.        , 0.05971968, ...,        nan,        nan,
#                nan],
#        [0.17261175, 0.05971968, 1.        , ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]])

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_b, cmap='coolwarm')
plt.show()

# %%
acf1 = sm.graphics.tsa.plot_pacf(births["Births"])
acf1

# %%
births.plot(x = "Date", y = ["lag_1", "Births"])
plt.show()

# %%
births.plot(x = "Date", y = ["lag_50", "Births"])
plt.show()

# %% [markdown]
# # Задание 4

# %%
import numpy as np
dfx = pd.DataFrame({'day':[int (i) for  i in range(0,51)],'sin':[np.sin(i) for i in range(0,51)]})

# %%
dfx
# Out:
#     day       sin
# 0     0  0.000000
# 1     1  0.841471
# 2     2  0.909297
# 3     3  0.141120
# 4     4 -0.756802
# 5     5 -0.958924
# 6     6 -0.279415
# 7     7  0.656987
# 8     8  0.989358
# 9     9  0.412118
# 10   10 -0.544021
# 11   11 -0.999990
# 12   12 -0.536573
# 13   13  0.420167
# 14   14  0.990607
# 15   15  0.650288
# 16   16 -0.287903
# 17   17 -0.961397
# 18   18 -0.750987
# 19   19  0.149877
# 20   20  0.912945
# 21   21  0.836656
# 22   22 -0.008851
# 23   23 -0.846220
# 24   24 -0.905578
# 25   25 -0.132352
# 26   26  0.762558
# 27   27  0.956376
# 28   28  0.270906
# 29   29 -0.663634
# 30   30 -0.988032
# 31   31 -0.404038
# 32   32  0.551427
# 33   33  0.999912
# 34   34  0.529083
# 35   35 -0.428183
# 36   36 -0.991779
# 37   37 -0.643538
# 38   38  0.296369
# 39   39  0.963795
# 40   40  0.745113
# 41   41 -0.158623
# 42   42 -0.916522
# 43   43 -0.831775
# 44   44  0.017702
# 45   45  0.850904
# 46   46  0.901788
# 47   47  0.123573
# 48   48 -0.768255
# ...

# %%
# Коррекция для каждого смещения от 1 до 100
for i in range(1, 101):
    dfx[f'lag_{i}'] = dfx['sin'].shift(-i)
# Out:
# /var/folders/9v/5p5m1vyn1l15r6g0mn4h76wc0000gn/T/ipykernel_1708/2625047546.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dfx[f'lag_{i}'] = dfx['sin'].shift(-i)
# /var/folders/9v/5p5m1vyn1l15r6g0mn4h76wc0000gn/T/ipykernel_1708/2625047546.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dfx[f'lag_{i}'] = dfx['sin'].shift(-i)

# %%
dfx
# Out:
#     day       sin     lag_1     lag_2     lag_3     lag_4     lag_5     lag_6  \
# 0     0  0.000000  0.841471  0.909297  0.141120 -0.756802 -0.958924 -0.279415
# 1     1  0.841471  0.909297  0.141120 -0.756802 -0.958924 -0.279415  0.656987
# 2     2  0.909297  0.141120 -0.756802 -0.958924 -0.279415  0.656987  0.989358
# 3     3  0.141120 -0.756802 -0.958924 -0.279415  0.656987  0.989358  0.412118
# 4     4 -0.756802 -0.958924 -0.279415  0.656987  0.989358  0.412118 -0.544021
# 5     5 -0.958924 -0.279415  0.656987  0.989358  0.412118 -0.544021 -0.999990
# 6     6 -0.279415  0.656987  0.989358  0.412118 -0.544021 -0.999990 -0.536573
# 7     7  0.656987  0.989358  0.412118 -0.544021 -0.999990 -0.536573  0.420167
# 8     8  0.989358  0.412118 -0.544021 -0.999990 -0.536573  0.420167  0.990607
# 9     9  0.412118 -0.544021 -0.999990 -0.536573  0.420167  0.990607  0.650288
# 10   10 -0.544021 -0.999990 -0.536573  0.420167  0.990607  0.650288 -0.287903
# ...

# %%
dfx1 = dfx.drop(columns =['day']).to_numpy()
corr_x = np.corrcoef(dfx1)
corr_x
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_x, cmap='coolwarm')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %%
acfx = sm.graphics.tsa.plot_pacf(dfx["sin"])
acfx
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
dfx.plot(x = "day", y = ["lag_1", "sin"])
plt.show()

# %%
dfx.plot(x = "day", y = ["lag_20", "sin"])
plt.show()

# %% [markdown]
# # Задание 5

# %% [markdown]
# Исследуем на стационарность датасет births

# %%
births = pd.read_csv("../data/births.csv")
births
# Out:
#            Date  Births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %%
from statistics import variance

print(f"Среднее:",round(births['Births'].mean(),3))
print(f"Дисперсия",round(variance(births['Births']),3))
print("\n")
# Out:
# Среднее: 41.981
# Дисперсия 53.997

# %%
# Определяем функцию для проверки стационарности
def check_stationarity(x, alpha=0.05):
    # Применяем тест Дики-Фуллера к выборке x
    test_stat, p_value, _, _, _, _ = sm.tsa.stattools.adfuller(x)
    # Сравниваем p-значение с уровнем значимости alpha
    if p_value < alpha:
        # Если p-значение меньше alpha, то ряд стационарен
        print(f"Выборка x является стационарной. p-значение = {p_value}")
    else:
        # Если p-значение больше или равно alpha, то ряд нестационарен
        print(f"Выборка x не является стационарной. p-значение = {p_value}")

# %%
check_stationarity(births['Births'])
sm.tsa.stattools.adfuller(births['Births'])
# Out:
# Выборка x является стационарной. p-значение = 5.2434129901498554e-05
# (-4.808291253559764,
#  5.2434129901498554e-05,
#  6,
#  358,
#  {'1%': -3.448748905151901,
#   '5%': -2.8696473721448728,
#   '10%': -2.5710891239349585},
#  2343.8290926464197)
